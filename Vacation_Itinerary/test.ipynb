# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import sys
from datetime import datetime
#sys.path.append("/Users/snehalborhade/Desktop/UT_Austin_BootCamp/Challenges/Challenge_6/WeatherPy/Vacation_Search/")
from Vacation_Search import hotel_df, clean_hotel_df


# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)
# Out:
# Hotel not found... skipping.

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
print(os.getcwd())
vacation_df
# Out:
# /Users/snehalborhade/Desktop/UT_Austin_BootCamp/Challenges/Challenge_6/WeatherPy/Vacation_Itinerary
#     City_ID                          City Country  Max Temp  \
# 0         1                       Rikitea      PF     72.86
# 1         2                      Hermanus      ZA     56.80
# 2         3                      Kedrovyy      RU     59.41
# 3         4                        Torbay      CA     72.37
# 4         5                        Kodiak      US     51.31
# 5         6                   Tuktoyaktuk      CA     57.20
# 6         7                        Avarua      CK     73.45
# 7         8                        Linxia      CN     64.18
# 8         9                    Nikolskoye      RU     73.29
# 9        10              Puerto Escondido      MX     85.03
# 10       11         Los Llanos De Aridane      ES     74.95
# 11       12                        Atuona      PF     76.59
# 12       13                   Port Alfred      ZA     58.17
# ...

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"]=="Springbok"]
vacation_end = vacation_df.loc[vacation_df["City"]=="Springbok"]
vacation_stop1 = vacation_df.loc[vacation_df["City"]=="Hermanus"]
vacation_stop2 = vacation_df.loc[vacation_df["City"]=="Port Elizabeth"]
vacation_stop3 = vacation_df.loc[vacation_df["City"]=="Port Alfred"]

# %%
import numpy as np

# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = tuple(zip(vacation_start["Lat"],vacation_start["Lng"]))
end = tuple(zip(vacation_end["Lat"],vacation_end["Lng"]))
stop1 = tuple(zip(vacation_stop1["Lat"],vacation_stop1["Lng"]))
stop2 = tuple(zip(vacation_stop2["Lat"],vacation_stop2["Lng"]))
stop3 = tuple(zip(vacation_stop3["Lat"],vacation_stop3["Lng"]))

print(start, end, stop1, stop2, stop3)
# Out:
# ((-29.6643, 17.8865),) ((-29.6643, 17.8865),) ((-34.4187, 19.2345),) ((-33.918, 25.5701),) ((-33.5906, 26.891),)

# %%
import numpy as np

# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0],vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0],vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0],vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0],vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0],vacation_stop3["Lng"].to_numpy()[0]

print(start, end, stop1, stop2, stop3)
# Out:
# (-29.6643, 17.8865) (-29.6643, 17.8865) (-34.4187, 19.2345) (-33.918, 25.5701) (-33.5906, 26.891)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
#locations = clean_hotel_df[["Lat", "Lng"]]
#direction_layer = gmaps.directions("start","end", waypoints1 = ["via:stop1" "via:stop2", "via:stop3"],
                                    #travel_mode = ["DRIVING", "BICYCLING", "WALKING"])

#fig.add_layer(direction_layer)

# Call the figure to plot the data.
#fig

#Latitude and Longitude pairs
Springbok = (-29.6643, 17.8865)
Hermanus = (-34.4187, 19.2345)
Port_Elizabeth = (-33.918, 25.5701)
Port_Alfred = (-33.5906, 26.891)
fig = gmaps.figure()



direction_layer = gmaps.directions_layer(Springbok, Springbok, waypoints = [Hermanus, Port_Elizabeth,Port_Alfred], 
                                        travel_mode = "DRIVING")

fig.add_layer(direction_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2, vacation_stop3, vacation_end],ignore_index=True)
itinerary_df
# Out:
#    City_ID            City Country  Max Temp Current Description      Lat  \
# 0       32       Springbok      ZA     57.74           clear sky -29.6643
# 1        2        Hermanus      ZA     56.80           clear sky -34.4187
# 2       46  Port Elizabeth      ZA     59.09     overcast clouds -33.9180
# 3       13     Port Alfred      ZA     58.17     overcast clouds -33.5906
# 4       32       Springbok      ZA     57.74           clear sky -29.6643
#
#        Lng                  Hotel Name
# 0  17.8865      Undulata Country Lodge
# 1  19.2345  Misty Waves Boutique Hotel
# 2  25.5701      39 On Nile Guest House
# 3  26.8910          The Halyards Hotel
# 4  17.8865      Undulata Country Lodge

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df[["Lat", "Lng"]]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
